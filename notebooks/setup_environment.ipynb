# %% [markdown]
# ## Install papermill
#
# https://github.com/nteract/papermill

# %%
# !pip3 install papermill
# Out:
# ...
#      |████████████████████████████████| 141 kB 3.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 66 kB 4.2 MB/s eta 0:00:011
# ...
#   Using cached PyYAML-5.4.1-cp36-cp36m-macosx_10_9_x86_64.whl (249 kB)
# ...
#      |████████████████████████████████| 62 kB 1.5 MB/s  eta 0:00:01
# ...
#   Using cached nbformat-5.1.3-py3-none-any.whl (178 kB)
# ...
#   Using cached entrypoints-0.3-py2.py3-none-any.whl (11 kB)
# ...
#      |████████████████████████████████| 97 kB 6.2 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 76 kB 1.1 MB/s  eta 0:00:01
# ...
#   Using cached async_generator-1.10-py3-none-any.whl (18 kB)
# ...
#   Using cached nest_asyncio-1.5.1-py3-none-any.whl (5.0 kB)
# ...
#   Using cached traitlets-4.3.3-py2.py3-none-any.whl (75 kB)
# ...
#      |████████████████████████████████| 122 kB 6.0 MB/s eta 0:00:01
# ...
#   Using cached jupyter_core-4.7.1-py3-none-any.whl (82 kB)
# ...
#      |████████████████████████████████| 1.3 MB 12.8 MB/s eta 0:00:01
# ...
